# %%
from chemdataextractor.EmiPeakExtract import EmissionPeakDB
from chemdataextractor import Document
import re
test = EmissionPeakDB(save_root='',file_list='',filename='')
d = Document.from_file(r'test.txt')
for p in d.paragraphs:
    test.classify(p=p, file_name='test.json')
# Out:
# results_auto: {'phosphor': ['Mg2SnO4 : 0.1 mol % Mn2+'], 'emission_peak': ['499'], 'excitation peak': ['227 and 268'], 'unit': 'nm', 'doi': 'test', 'note': 'results_auto'}
# results_multisom: {'phosphor': 'Mg2SnO4 : 0.1 mol % Ti4+ , 0.25 mol % Mn2+', 'emission_peak': ['442', '497'], 'excitation peak': ['244'], 'unit': 'nm', 'doi': 'test', 'note': 'results_multi'}
# results_multisom: {'phosphor': 'Zn2SnO4:Eu3+', 'emission_peak': ['589', '594', '600', '610'], 'unit': 'nm', 'doi': 'test', 'note': 'results_multi'}
# results_multisom: {'phosphor': 'YF3 : Ce3+ , Dy3+', 'emission_peak': ['478', '571', '658'], 'unit': 'nm', 'doi': 'test', 'note': 'results_multi'}
